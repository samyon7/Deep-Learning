# %% [markdown]
# # Imports

# %%
#!pip install -q tensorflow==2.0.0
#!pip install category_encoders

#Helpers
import math
import warnings
from datetime import datetime,timedelta
from sklearn.model_selection import train_test_split
#Data manipulating
import pandas as pd
from pandas.tseries.offsets import DateOffset
import numpy as np
# Deep Learning and Neural Networks
import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
#Algoritmos
#ARIMAX
import statsmodels.api as sm
from statsmodels.tsa.api import ExponentialSmoothing,SimpleExpSmoothing, Holt
from sklearn.pipeline import Pipeline
#Data Transform
#from category_encoders import OneHotEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# Using TensorFlow backend.

# %% [markdown]
# # Utils Functions

# %%
#Generates a new Dataframe forwarding dates
def createFutureDF(df,start_date,days_forward):
  future_dates=[start_date+ DateOffset(days=x)for x in range(0,days_forward)] # Ver 3 anos para frente
  future_df=pd.DataFrame(index=future_dates[1:],columns=df.columns)
  return future_df

#Creates a multi-dimension dataset for LSTM networks
def create_lstm_dataset(X, y, time_steps=1):
  Xs, ys = [], []
  for i in range(len(X) - time_steps):
      v = X.iloc[i:(i + time_steps)].values
      Xs.append(v)
      ys.append(y.iloc[i + time_steps])
  return np.array(Xs), np.array(ys)

# %% [markdown]
# # Data Load & Describe

# %%
# Get the DataSet
df = pd.read_csv('notas.csv')
# Tratamento dos dados
df['data'] = pd.to_datetime(df["data"])
df.index = df['data']

# %%
# Prepara o DataFrame do futuro
future_df = createFutureDF(df,df.index[-1],365*3)

future_df['data'] = pd.to_datetime(future_df.index)
future_df['ano']  = future_df.data.dt.year
future_df['dia']  = future_df.data.dt.day
future_df['mes']  = future_df.data.dt.month
future_df['dia_semana'] = future_df.data.dt.weekday
future_df['itens'] = df.itens.median()

# %% [markdown]
# #### Descrição dos dados

# %%
#Tipos de dados
print(df.dtypes)
# Out:
# data          datetime64[ns]
# count                  int64
# itens                  int64
# ano                    int64
# mes                    int64
# dia                    int64
# dia_semana             int64
# dtype: object

# %%
df.tail()
# Out:
#                  data  count  itens   ano  mes  dia  dia_semana
# data
# 2020-02-19 2020-02-19     37     34  2020    2   19           4
# 2020-02-20 2020-02-20     13     21  2020    2   20           5
# 2020-02-21 2020-02-21     13     12  2020    2   21           6
# 2020-02-22 2020-02-22     20     19  2020    2   22           7
# 2020-02-24 2020-02-24      4      4  2020    2   24           2

# %%
df.describe()
# Out:
#              count        itens  ...          dia   dia_semana
# count  1520.000000  1520.000000  ...  1520.000000  1520.000000
# mean     22.498684    24.836842  ...    15.770395     4.480263
# std      21.882895    24.202861  ...     8.749490     1.751029
# min       1.000000    -5.000000  ...     1.000000     1.000000
# 25%       9.000000    10.000000  ...     8.000000     3.000000
# 50%      17.000000    19.000000  ...    16.000000     4.000000
# 75%      29.000000    32.000000  ...    23.000000     6.000000
# max     280.000000   264.000000  ...    31.000000     7.000000
#
# [8 rows x 6 columns]

# %%
df.hist(figsize=(15,10),bins=5)
plt.show()

# %%
# plot the heatmap
#Heatmap
corrmat = df.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(12,12))
#plot heat map
g=sns.heatmap(df[top_corr_features].corr(),annot=True,cmap="RdYlGn",)

# %%
#PLotar o Grafico
fig, ax = plt.subplots()
ax.figure.set_size_inches(19,8)
#print(X_train.reshape(1,95))
plt.title('Quantidade de Compras')
plt.ylabel("Compras")
plt.xlabel("Data")
ax.plot(df.index,df['count'],label='Quantidade de Compras')
ax.legend()
plt.show()

# %% [markdown]
# # Data Cleaning e Transform

# %%
train_data = df.drop(columns=['data'])[:'2019-04-01']
test_data = df.drop(columns=['data'])['2019-04-01':]

X_columns = ['dia','mes','dia_semana'] # retirado 'ano'

X_train = train_data[X_columns]
y_train = train_data[['count']]

X_test = test_data[X_columns]
y_test= test_data[['count']]

# %%
#PLotar o Grafico de treino e teste
fig, ax = plt.subplots()
ax.figure.set_size_inches(19,8)
plt.title('Quantidade de Compras')
plt.ylabel("Compras")
plt.xlabel("Data")
ax.plot(X_train.index,y_train['count'],label='Train')
ax.plot(X_test.index,y_test['count'],label='Test')
ax.legend()
plt.show()

# %%
print(len(X_test),len(y_test))
# Out:
# 276 276

# %% [markdown]
# ### Reescalar os dados

# %%
#Rescalar os dados
scalerTrain = StandardScaler()
scalerTest = StandardScaler()

X_train = scalerTrain.fit_transform(X_train)
X_test= scalerTest.fit_transform(X_test)

# Transformar novamente em pd
X_train_scaled = pd.DataFrame(X_train, index=train_data.index, columns=X_columns)
X_test_scaled = pd.DataFrame(X_test, index=test_data.index, columns=X_columns)

# %% [markdown]
# # Feature Selection (sem uso)

# %%
from sklearn.feature_selection import SelectKBest # Melhor para dados categoricos e features numericas
from sklearn.feature_selection import chi2 # Categoricos
from sklearn.feature_selection import RFE #TODO # Bom para regressoes

bestfeatures = SelectKBest( k=2)
fit = bestfeatures.fit(df[X_columns],df['count'])
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(X_train.columns)
#concat two dataframes for better visualization 
featureScores = pd.concat([dfcolumns,dfscores],axis=1)
featureScores.columns = ['Specs','Score']  #naming the dataframe columns
featureScores.nlargest(3,'Score') #print X best features

plt.barh(width=featureScores.nlargest(3,'Score').Score,y=featureScores.nlargest(3,'Score').Specs)
best_columns = featureScores.nlargest(2,'Score').Specs.values

# %% [markdown]
# # Treino com LSTM

# %%
time_steps = 7 #numero de dias que olha pra ras
#Gera dados de treino e teste
X_train_lstm, y_train_lstm = create_lstm_dataset(X_train_scaled,y_train, time_steps)
X_test_lstm, y_test_lstm = create_lstm_dataset(X_test_scaled,y_test, time_steps)

print(X_train_lstm.shape, y_train_lstm.shape)
print(X_test_lstm.shape, y_test.shape)
# Out:
# (1146, 7, 3) (1146, 1)
# (271, 7, 3) (278, 1)

# %%
#Melhores parametros ate agora
#Time steps = 7
epochs = 4060
batch_size = 32
loss='mean_squared_error'
optimizer='adam'
dropout = 0.2 # dropout para cada lstm
#neurons = 100, 100
#Train Score: 0.41 MSE (0.64 RMSE)
#Test Score: 11.97 MSE (3.46 RMSE)

model = keras.Sequential()
#model.add(keras.layers.LSTM(8, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(keras.layers.LSTM(50, activation='relu', return_sequences=True, input_shape=(X_train_lstm.shape[1], X_train_lstm.shape[2])))
model.add(keras.layers.Dropout(dropout))
model.add(keras.layers.LSTM(50,return_sequences=True))
model.add(keras.layers.Dropout(dropout))
model.add(keras.layers.LSTM(50,return_sequences=True))
model.add(keras.layers.Dropout(dropout))
model.add(keras.layers.LSTM(50))
model.add(keras.layers.Dense(1))
model.compile(loss=loss,optimizer=optimizer)
#model.fit(X_train_lstm, y_train_lstm, epochs=epochs, batch_size=batch_size, verbose=1, shuffle=False,)
#epoch_hist = []
#for epoch in range(epochs):
#  print(epoch,' de ', epochs)
#  result = model.fit(X_train_lstm, y_train_lstm,batch_size,shuffle=False,verbose=0)
#  epoch_hist.append(result.history["loss"][0])
#  print('loss',result.history['loss'] )
#  clear_output(wait=True)
#  plt.plot(epoch_hist)
#  plt.show()

# %%
#Treina o modelo (quantas vezes quiser)
model.fit(X_train_lstm, y_train_lstm, epochs=epochs, batch_size=batch_size, verbose=1, shuffle=False,)
# Out:
# Streaming output truncated to the last 5000 lines.
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 24.3857
# Epoch 1562/4060
# 1146/1146 [==============================] - 1s 999us/sample - loss: 28.6840
# Epoch 1563/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 27.0681
# Epoch 1564/4060
# 1146/1146 [==============================] - 1s 987us/sample - loss: 22.7853
# Epoch 1565/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 25.8396
# Epoch 1566/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 25.7915
# Epoch 1567/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 22.2364
# Epoch 1568/4060
# 1146/1146 [==============================] - 1s 960us/sample - loss: 25.7697
# Epoch 1569/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 23.8688
# Epoch 1570/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 24.3989
# Epoch 1571/4060
# 1146/1146 [==============================] - 1s 976us/sample - loss: 24.2127
# Epoch 1572/4060
# 1146/1146 [==============================] - 1s 991us/sample - loss: 27.0994
# Epoch 1573/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 24.5238
# Epoch 1574/4060
# 1146/1146 [==============================] - 1s 965us/sample - loss: 22.6958
# Epoch 1575/4060
# 1146/1146 [==============================] - 1s 989us/sample - loss: 21.0864
# Epoch 1576/4060
# 1146/1146 [==============================] - 1s 994us/sample - loss: 24.3348
# Epoch 1577/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 23.6489
# Epoch 1578/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 21.3800
# Epoch 1579/4060
# 1146/1146 [==============================] - 1s 993us/sample - loss: 20.6140
# Epoch 1580/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 25.1607
# Epoch 1581/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 23.8774
# Epoch 1582/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 28.1250
# Epoch 1583/4060
# 1146/1146 [==============================] - 1s 991us/sample - loss: 26.1380
# Epoch 1584/4060
# 1146/1146 [==============================] - 1s 986us/sample - loss: 20.7522
# Epoch 1585/4060
# 1146/1146 [==============================] - 1s 971us/sample - loss: 25.5829
# Epoch 1586/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 48.3391
# Epoch 1587/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 78.6527
# Epoch 1588/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 54.5023
# Epoch 1589/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 56.4173
# Epoch 1590/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 45.8180
# Epoch 1591/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 38.2794
# Epoch 1592/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 34.9101
# Epoch 1593/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 30.5042
# Epoch 1594/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 34.8252
# Epoch 1595/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 28.6017
# Epoch 1596/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 31.3434
# Epoch 1597/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 30.1118
# Epoch 1598/4060
# 1146/1146 [==============================] - 1s 999us/sample - loss: 29.0166
# Epoch 1599/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 27.3536
# Epoch 1600/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 24.2928
# Epoch 1601/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 25.2223
# Epoch 1602/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 28.9173
# Epoch 1603/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 39.8149
# Epoch 1604/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 28.1365
# Epoch 1605/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 28.7326
# Epoch 1606/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss:
4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 18.9212
# Epoch 3914/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 19.9739
# Epoch 3915/4060
# 1146/1146 [==============================] - 1s 995us/sample - loss: 18.7718
# Epoch 3916/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 20.2504
# Epoch 3917/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 22.9169
# Epoch 3918/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 18.8160
# Epoch 3919/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 16.7283
# Epoch 3920/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 17.3294
# Epoch 3921/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 18.0691
# Epoch 3922/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 17.4406
# Epoch 3923/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 17.9841
# Epoch 3924/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 21.0688
# Epoch 3925/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 16.5508
# Epoch 3926/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 19.2309
# Epoch 3927/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 21.3489
# Epoch 3928/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 15.8921
# Epoch 3929/4060
# 1146/1146 [==============================] - 1s 998us/sample - loss: 19.6765
# Epoch 3930/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 17.7764
# Epoch 3931/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 16.3207
# Epoch 3932/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 15.5542
# Epoch 3933/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 18.7857
# Epoch 3934/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 17.3288
# Epoch 3935/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 18.5318
# Epoch 3936/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 20.3955
# Epoch 3937/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 28.3953
# Epoch 3938/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 31.5994
# Epoch 3939/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 23.0443
# Epoch 3940/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 32.1613
# Epoch 3941/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 41.3675
# Epoch 3942/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 31.7810
# Epoch 3943/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 19.6724
# Epoch 3944/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 25.4374
# Epoch 3945/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 18.2286
# Epoch 3946/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 20.4475
# Epoch 3947/4060
# 1146/1146 [==============================] - 1s 995us/sample - loss: 18.8704
# Epoch 3948/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 21.8684
# Epoch 3949/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 19.4002
# Epoch 3950/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 21.1457
# Epoch 3951/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 23.0396
# Epoch 3952/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 19.2409
# Epoch 3953/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 16.0656
# Epoch 3954/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 19.5660
# Epoch 3955/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 20.0976
# Epoch 3956/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 17.1907
# Epoch 3957/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 18.7842
# Epoch 3958/4060
# 1146/1146 [==============================] - 1s 999us/sample - loss: 24.3288
# Epoch 3959/4060
# 1146/1146 [==============================] - 1s 1000us/sample - loss: 18.9284
# Epoch 3960/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 18.6402
# Epoch 3961/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 19.1058
# Epoch 3962/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 17.6083
# Epoch 3963/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 16.3054
# Epoch 3964/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 14.0555
# Epoch 3965/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 17.1626
# Epoch 3966/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 17.5347
# Epoch 3967/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 24.3413
# Epoch 3968/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 30.0362
# Epoch 3969/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 27.0294
# Epoch 3970/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 25.0423
# Epoch 3971/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 33.2961
# Epoch 3972/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 31.3519
# Epoch 3973/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 23.1072
# Epoch 3974/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 17.5150
# Epoch 3975/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 16.3394
# Epoch 3976/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 16.7874
# Epoch 3977/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 18.3017
# Epoch 3978/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 22.5110
# Epoch 3979/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 17.1599
# Epoch 3980/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 16.0007
# Epoch 3981/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 18.3168
# Epoch 3982/4060
# 1146/1146 [==============================] - 1s 1000us/sample - loss: 15.6073
# Epoch 3983/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 17.4272
# Epoch 3984/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 14.9826
# Epoch 3985/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 16.2203
# Epoch 3986/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 18.1117
# Epoch 3987/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 17.9726
# Epoch 3988/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 14.3827
# Epoch 3989/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 20.1842
# Epoch 3990/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 16.2802
# Epoch 3991/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 16.0882
# Epoch 3992/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 20.6557
# Epoch 3993/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 23.7309
# Epoch 3994/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 22.9584
# Epoch 3995/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 20.0114
# Epoch 3996/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 17.5023
# Epoch 3997/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 21.7231
# Epoch 3998/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 18.6889
# Epoch 3999/4060
# 1146/1146 [==============================] - 1s 989us/sample - loss: 19.5193
# Epoch 4000/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 18.9250
# Epoch 4001/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 42.8563
# Epoch 4002/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 31.3868
# Epoch 4003/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 26.0103
# Epoch 4004/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 26.3478
# Epoch 4005/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 23.0762
# Epoch 4006/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 19.8275
# Epoch 4007/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 19.3175
# Epoch 4008/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 19.0913
# Epoch 4009/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 20.7059
# Epoch 4010/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 16.7980
# Epoch 4011/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 20.1179
# Epoch 4012/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 16.8947
# Epoch 4013/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 18.5476
# Epoch 4014/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 17.7730
# Epoch 4015/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 15.8397
# Epoch 4016/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 17.9749
# Epoch 4017/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 14.7282
# Epoch 4018/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 17.2524
# Epoch 4019/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 24.2452
# Epoch 4020/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 16.4042
# Epoch 4021/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 18.9527
# Epoch 4022/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 14.3893
# Epoch 4023/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 16.1395
# Epoch 4024/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 21.0606
# Epoch 4025/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 17.5482
# Epoch 4026/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 17.9523
# Epoch 4027/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 18.6482
# Epoch 4028/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 19.9992
# Epoch 4029/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 15.3628
# Epoch 4030/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 22.7751
# Epoch 4031/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 29.5800
# Epoch 4032/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 55.3653
# Epoch 4033/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 33.5805
# Epoch 4034/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 31.1756
# Epoch 4035/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 23.0128
# Epoch 4036/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 23.6866
# Epoch 4037/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 20.2234
# Epoch 4038/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 22.1464
# Epoch 4039/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 19.0314
# Epoch 4040/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 17.3928
# Epoch 4041/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 19.5662
# Epoch 4042/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 19.4772
# Epoch 4043/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 18.8611
# Epoch 4044/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 20.6355
# Epoch 4045/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 22.2199
# Epoch 4046/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 16.8074
# Epoch 4047/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 22.1492
# Epoch 4048/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 27.1367
# Epoch 4049/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 16.9046
# Epoch 4050/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 18.4050
# Epoch 4051/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 21.1797
# Epoch 4052/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 17.7934
# Epoch 4053/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 18.1804
# Epoch 4054/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 15.3812
# Epoch 4055/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 19.0694
# Epoch 4056/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 21.6185
# Epoch 4057/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 20.3897
# Epoch 4058/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 17.9106
# Epoch 4059/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 20.9190
# Epoch 4060/4060
# 1146/1146 [==============================] - 1s 1ms/sample - loss: 16.5127

# %%
from IPython.display import clear_output
epoch_hist = []
# %matplotlib inline
for epoch in range(epochs):
  print(epoch,' de ', epochs)
  result = model.fit(X_train_lstm, y_train_lstm,batch_size=batch_size,shuffle=False,verbose=0)
  epoch_hist.append(result.history["loss"][0])
  print('loss',result.history['loss'] )
  clear_output(wait=True)
  plt.plot(epoch_hist)
  plt.show()
# Out:
# 33  de  4060
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-38-c81d58cd8afc> in <module>()
#       4 for epoch in range(epochs):
#       5   print(epoch,' de ', epochs)
# ----> 6   result = model.fit(X_train_lstm, y_train_lstm,batch_size=batch_size,shuffle=False,verbose=0)
#       7   epoch_hist.append(result.history["loss"][0])
#       8   print('loss',result.history['loss'] )
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     725         max_queue_size=max_queue_size,
#     726         workers=workers,
# --> 727         use_multiprocessing=use_multiprocessing)
#     728
#     729   def evaluate(self,
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/engine/training_arrays.py in fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, **kwargs)
#     673         validation_steps=validation_steps,
#     674         validation_freq=validation_freq,
# --> 675         steps_name='steps_per_epoch')
#     676
#     677   def evaluate(self,
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/engine/training_arrays.py in model_iteration(model, inputs, targets, sample_weights, batch_size, epochs, verbose, callbacks, val_inputs, val_targets, val_sample_weights, shuffle, initial_epoch, steps_per_epoch, validation_steps, validation_freq, mode, validation_in_fit, prepared_feed_values_from_dataset, steps_name, **kwargs)
#     392
#     393         # Get outputs.
# --> 394         batch_outs = f(ins_batch)
#     395         if not isinstance(batch_outs, list):
#     396           batch_outs = [batch_outs]
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/backend.py in __call__(self, inputs)
#    3474
#    3475     fetched = self._callable_fn(*array_vals,
# -> 3476                                 run_metadata=self.run_metadata)
#    3477     self._call_fetch_callbacks(fetched[-len(self._fetches):])
#    3478     output_structure = nest.pack_sequence_as(
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/client/session.py in __call__(self, *args, **kwargs)
#    1470         ret = tf_session.TF_SessionRunCallable(self._session._session,
#    1471                                                self._handle, args,
# -> 1472                                                run_metadata_ptr)
#    1473         if run_metadata:
#    1474           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
# Estimate model performance
trainScore = model.evaluate(X_train_lstm, y_train_lstm, verbose=0)
print('Train Score: %.2f MSE (%.2f RMSE)' % (trainScore, math.sqrt(trainScore)))
testScore = model.evaluate(X_test_lstm, y_test_lstm, verbose=0)
print('Test Score: %.2f MSE (%.2f RMSE)' % (testScore, math.sqrt(testScore)))
# Out:
# Train Score: 11.21 MSE (3.35 RMSE)
# Test Score: 433.71 MSE (20.83 RMSE)

# %%
#Save or load model weights or complete model
#model.load_weights('drive/My Drive/Colab Notebooks/Monjua/Weights/notas_wv_5.h5')
#model.save_weights('notas_wv_5.h5')
#model.save('notas_m_5.h5')

# %%
#Prever e criar os dataframes
prediction = model.predict(X_test_lstm)
prediction_lstm_df = pd.DataFrame(prediction,index=y_test[:len(prediction)].index,columns=y_test.columns)
future_df_lstm_scaled = pd.DataFrame(scalerTest.transform(future_df[X_columns]),index=future_df.index,columns=X_columns)
X_forward_lstm, teste2 = create_lstm_dataset(future_df_lstm_scaled,future_df_lstm_scaled[['dia']], time_steps)
future_df_lstm_prediction = pd.DataFrame(model.predict(X_forward_lstm),index=future_df_lstm_scaled[:len(X_forward_lstm)].index,columns=y_test.columns)

# %%
fig, ax = plt.subplots()
ax.figure.set_size_inches(20,8)
#print(X_train.reshape(1,95))
ax.plot(y_train,label='Train')
ax.plot(y_test,label='Test')
ax.plot(prediction_lstm_df,label='Prediction',linestyle='--')
ax.plot(future_df_lstm_prediction,label='Forward')
ax.tick_params(axis='both', colors='white')
ax.legend()
plt.show()

# %% [markdown]
# # Prophet

# %%
from fbprophet import Prophet
p_df = df.copy()
p_df.drop(["itens","ano","mes","dia","dia_semana"],axis=1,inplace=True)
p_df.columns = ["ds","y"]

# %%
m = Prophet()
m.fit(p_df)
# Out:
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
future = m.make_future_dataframe(periods=720)
forecast = m.predict(future)
forecast.index = forecast.ds

# %%
forecast.head()
# Out:
#                    ds     trend  ...  multiplicative_terms_upper       yhat
# ds                               ...
# 2015-01-05 2015-01-05  6.905690  ...                         0.0   9.462768
# 2015-01-07 2015-01-07  6.926801  ...                         0.0   7.080224
# 2015-01-08 2015-01-08  6.937356  ...                         0.0  10.402207
# 2015-01-09 2015-01-09  6.947911  ...                         0.0  10.934380
# 2015-01-16 2015-01-16  7.021798  ...                         0.0   8.684207
#
# [5 rows x 19 columns]

# %%
fig1 = m.plot(forecast)
fig1.set_size_inches((25,8))

# %%
fig2 = m.plot_components(forecast)

# %%
fig, ax = plt.subplots()
ax.figure.set_size_inches(20,8)
#print(X_train.reshape(1,95))
ax.plot(y_train,label='Train')
ax.plot(y_test,label='Test')
ax.plot(prediction_lstm_df,label='Prediction')
ax.plot(future_df_lstm_prediction,label='Forward')
ax.plot(forecast['yhat'][prediction_lstm_df.index[-1]:],label='Prophet Forecast')
ax.tick_params(axis='both', colors='white')
ax.legend()
plt.show()
